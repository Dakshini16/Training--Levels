# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
x=np.arange(1,10)
y=np.arange(1,10)
plt.plot(x,y,'r--')
plt.title("line chart")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()
