# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
a=np.random.randint(0,10,size=10)
sns.boxplot(a)
plt.title("boxplot")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()
